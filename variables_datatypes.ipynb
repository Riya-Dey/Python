# %%
print("Hey! it's RD")
# Out:
# Hey! it's RD

# %%
#Varibales

name = "Riya Dey"
age = 25
working_hrs = 9.5
is_working = True
print(f"Hi! my name is {name} & I'm {age} years old")
print("Hi! I'm {} & my age is {}".format(name,age))
print("Riya","Dey", sep="~")
print(f"My working hours is - {working_hrs:.2f}")
print(f"Name: {name:>10}")
print(f"age: {age:05b} which is {age}")
# Out:
# Hi! my name is Riya Dey & I'm 25 years old
# Hi! I'm Riya Dey & my age is 25
# Riya~Dey
# My working hours is - 9.50
# Name:   Riya Dey
# age: 11001 which is 25

# %%
##Data Types

#String
str1 = "G"
str2 = 'i'
str3 = """t
Hub
"""
print(str1+str2+str3)

text = "python"
print(text[0])
print(text[1])
print(text[-1])

#Numeric

#integer
num1 = 5
num2 = 7
print(f"\nExamples of Integer number - {num1}, {num2}")

#Float
f1 = 3.14
f2 = -4.1
print(f"Examples of float number - {f1}, {f2}")

#Complex
com1 = 2 + 5j
com2 = 5 + 4j
print(f"Examples of complex number - {com1}, {com2}")
print(type(com1))

#Boolean
is_true = True
res1 = 5>4
res2 = 7==21
print(res1)
print(res2)
# Out:
# Git
# Hub
#
# p
# y
# n
#
# Examples of Integer number - 5, 7
# Examples of float number - 3.14, -4.1
# Examples of complex number - (2+5j), (5+4j)
# <class 'complex'>
# True
# False
